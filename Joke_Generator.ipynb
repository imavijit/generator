# %%
mkdir finetune

# %%
cd finetune
# Out:
# /content/finetune

# %%
! git clone "https://github.com/nshepperd/gpt-2.git"
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 310, done.
# remote: Total 310 (delta 0), reused 0 (delta 0), pack-reused 310
# Receiving objects: 100% (310/310), 4.40 MiB | 6.88 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %% [markdown]
# Move "train.py" & "encode.py" to src folder

# %%
% cd gpt-2
# Out:
# /content/finetune/gpt-2

# %%
! python download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 1.04Mit/s]
# Fetching encoder.json: 1.04Mit [00:00, 62.6Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 1.28Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:07, 67.3Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 5.99Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 19.4Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 57.4Mit/s]

# %% [markdown]
# Move "models" folder to "src" folder

# %%
% cd src
# Out:
# /content/finetune/gpt-2/src

# %% [markdown]
# Upload custom dataset(jokes.txt) and move it to src folder

# %%
! python encode.py jokes.txt jokes.npz
# Out:
# Reading files
# 100% 1/1 [00:00<00:00,  7.31it/s]
# Writing jokes.npz

# %%
# !pip3 install toposort==1.5

# %%
! python train.py --dataset jokes.npz --sample_every 50 --sample_num 2
# Out:
# WARNING:tensorflow:From /content/finetune/gpt-2/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/finetune/gpt-2/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From train.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:91: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...
