# %%
mkdir generator

# %%
cd generator
# Out:
# /content/generator

# %%
! git clone "https://github.com/nshepperd/gpt-2.git"
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 370, done.
# remote: Total 370 (delta 0), reused 0 (delta 0), pack-reused 370
# Receiving objects: 100% (370/370), 4.42 MiB | 17.82 MiB/s, done.
# Resolving deltas: 100% (201/201), done.

# %% [markdown]
# Move "train.py" & "encode.py" to src folder

# %%
% cd gpt-2
# Out:
# /content/generator/gpt-2

# %%
! python download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 781kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 37.6Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 977kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:09, 50.5Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 3.49Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 21.2Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 24.1Mit/s]

# %% [markdown]
# Move "models" folder to "src" folder

# %%
% cd src
# Out:
# /content/generator/gpt-2/src

# %% [markdown]
# Upload custom dataset(final_data.txt) and move it to src folder

# %%
! python encode.py final_data.txt data.npz
# Out:
# 2020-04-25 18:01:25.664198: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Reading files
# 100% 1/1 [00:00<00:00,  3.57it/s]
# Writing data.npz

# %%
# !pip3 install toposort==1.5

# %%
# %tensorflow_version 1.9
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.9`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
! python train.py --dataset data.npz --sample_every 500 --sample_num 2
# Out:
# Streaming output truncated to the last 5000 lines.
# [11735 | 299.87] loss=0.01 avg=0.02
# [11736 | 300.13] loss=0.01 avg=0.02
# [11737 | 300.39] loss=0.02 avg=0.02
# [11738 | 300.66] loss=0.01 avg=0.02
# [11739 | 300.92] loss=0.03 avg=0.02
# [11740 | 301.18] loss=0.02 avg=0.02
# [11741 | 301.44] loss=0.03 avg=0.02
# [11742 | 301.70] loss=0.01 avg=0.02
# [11743 | 301.96] loss=0.01 avg=0.02
# [11744 | 302.23] loss=0.02 avg=0.02
# [11745 | 302.50] loss=0.02 avg=0.02
# [11746 | 302.76] loss=0.04 avg=0.02
# [11747 | 303.02] loss=0.03 avg=0.02
# [11748 | 303.28] loss=0.02 avg=0.02
# [11749 | 303.53] loss=0.03 avg=0.02
# [11750 | 303.80] loss=0.02 avg=0.02
# [11751 | 304.07] loss=0.01 avg=0.02
# [11752 | 304.33] loss=0.01 avg=0.02
# [11753 | 304.60] loss=0.04 avg=0.02
# [11754 | 304.86] loss=0.01 avg=0.02
# [11755 | 305.12] loss=0.03 avg=0.02
# [11756 | 305.37] loss=0.01 avg=0.02
# [11757 | 305.63] loss=0.01 avg=0.02
# [11758 | 305.90] loss=0.03 avg=0.02
# ...

# %%
! pip3 install fire

# %%
! python generate_unconditional_samples.py --model_name 117M
